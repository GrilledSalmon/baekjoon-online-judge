# %% [markdown]
# # 1463 1로 만들기
# 211204
# - 소감
# - 아이디어
# - 알고리즘 분류
# - 티어

# %%
N = int(input())

# %%
cache = {}
cache[1] = 0

def to1_need(n):
    ans = cache.get(n, None)
    if ans != None:
        return ans
    if n%3 != 0 and n%2 != 0:
        ans = to1_need(n-1) + 1
        cache[n] = ans
        return ans
    elif n%3 != 0:
        ans = min(to1_need(n//2) + 1, to1_need(n-1) + 1)
        cache[n] = ans
        return ans
    elif n%2 != 0:
        ans = min(to1_need(n//3) + 1, to1_need(n-1) + 1)
        cache[n] = ans
        return ans
    else:
        ans = min(to1_need(n//3) + 1, to1_need(n//2) + 1, to1_need(n-1) + 1)
        cache[n] = ans
        return ans

print(to1_need(N))
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-22-2de3480b0478> in <module>
#      25         return ans
#      26
# ---> 27 print(to1_need(N))
#
# <ipython-input-22-2de3480b0478> in to1_need(n)
#      13         return ans
#      14     elif n%3 != 0:
# ---> 15         ans = min(to1_need(n//2) + 1, to1_need(n-1) + 1)
#      16         cache[n] = ans
#      17         return ans
#
# <ipython-input-22-2de3480b0478> in to1_need(n)
#       9     #     return 0
#      10     if n%3 != 0 and n%2 != 0:
# ---> 11         ans = to1_need(N-1) + 1
#      12         cache[n] = ans
#      13         return ans
#
# <ipython-input-22-2de3480b0478> in to1_need(n)
#      17         return ans
#      18     elif n%2 != 0:
# ---> 19         ans = min(to1_need(n//3) + 1, to1_need(n-1) + 1)
#      20         cache[n] = ans
#      21         return ans
#
# ...

# %%
cache
# Out:
# {1: 0, 2: 1, 3: 1, 4: 2}

# %%
cache = {}

def to1_need(n, cnt=0):
    cnt2 = cache.get(n, None)
    if cnt2 != None:
        return cnt + cnt2
    if n == 1:
        cache[N] = cnt
        return cnt
    if n%3 != 0 and n%2 != 0:
        return to1_need(N-1, cnt+1)
    elif n%3 != 0:
        return min(to1_need(n//2, cnt+1), to1_need(n-1, cnt+1))
    elif n%2 != 0:
        return min(to1_need(n//3, cnt+1), to1_need(n-1, cnt+1))
    else:
        return min(to1_need(n//3, cnt+1), to1_need(n//2, cnt+1), to1_need(n-1, cnt+1))

print(to1_need(N))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-bfb8590c6424> in <module>
#      17         return min(to1_need(N//3, cnt+1), to1_need(N//2, cnt+1), to1_need(N-1, cnt+1))
#      18
# ---> 19 print(to1_need(N))
#
# <ipython-input-11-bfb8590c6424> in to1_need(N, cnt)
#      11         return to1_need(N-1, cnt+1)
#      12     elif N%3 != 0:
# ---> 13         return min(to1_need(N//2, cnt+1), to1_need(N-1, cnt+1))
#      14     elif N%2 != 0:
#      15         return min(to1_need(N//3, cnt+1), to1_need(N-1, cnt+1))
#
# <ipython-input-11-bfb8590c6424> in to1_need(N, cnt)
#      11         return to1_need(N-1, cnt+1)
#      12     elif N%3 != 0:
# ---> 13         return min(to1_need(N//2, cnt+1), to1_need(N-1, cnt+1))
#      14     elif N%2 != 0:
#      15         return min(to1_need(N//3, cnt+1), to1_need(N-1, cnt+1))
#
# ...

# %%
N
# Out:
# 1000

# %%
cache
# Out:
# {1: 12}
