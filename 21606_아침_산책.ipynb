# %% [markdown]
# # 21606 아침 산책
# - 소감 : 정말 좋은 문제라고 생각한다. 문제를 풀기 위해서는 DFS뿐만 아니라 DFS를 쓰면서 메모리를 적게쓰기 위한 방법을 고민해야 하고, 트리의 특성에 대해서도 많이 생각해봐야 한다. 그리고 그래프 지식을 이용하면서도 시간복잡도를 낮추기 위해 매우 다양한 고민을 해봐야 한다. 시간복잡도와 메모리복잡도를 낮추기 위해 매우 다양한 아이디어를 시도했고, 그러면서 조금씩 개선해서 맞출 수 있었다. 아주 좋은 문제. 노드의 수가 20만 개로 상당히 많기 때문에 한 번의 트리 순회로 문제를 해결해야 한다.
# - 아이디어 : 하나의 실내에서 시작해 트리를 순회하는 경우를 상상해보자. 실외를 만나면 계속 진행하고 실내를 만나면 하나의 경로를 찾은 것이다. 근데, 만약 경로를 찾는 과정에서 하나의 실외라도 거쳤다면, 그 실외를 거쳐 도달한 경로의 끝점은 무조건 서로 연결될 수 있다.(예를들어 1-2-3, 1-2-4가 가능하면, 3-2-4도 무조건 가능) 따라서 중간에 실외를 거친 경로는 group_num을 부여해 따로 카운트하고 최종 total_cnt에 합할 때 nC2로 경우의 수를 더해주면 순회를 줄일 수 있다. 그리고 종점에 도달한 경우엔 종점을 새로운 시작점으로 다시 순회를 시작한다.
# - 알고리즘 분류
#     - 수학
#     - 그래프 이론
#     - 그래프 탐색
#     - 트리
#     - 깊이 우선 탐색
#     - 조합론
# - 티어 : 골드 3

# %%
# 21606 DFS로 푼 거
from collections import deque
import sys
sys.setrecursionlimit(1000000)
# input = sys.stdin.readline

N = int(input())
inner_outer = input().rstrip()
adj_list = [[] for _ in range(N+1)]
for _ in range(N-1):
    u, v = map(int, input().split())
    adj_list[u].append(v)
    adj_list[v].append(u)

def n_comb_2(n):
    return n*(n-1)//2

total_cnt = [0]
visited = [0]*(N+1)
root_queue = deque()

def how_many_path(root):
    now_cnt = []
    def dfs(node=root, group_num=None):
        for adj_node in adj_list[node]:
            if not visited[adj_node]:
                visited[adj_node] = 1
                if inner_outer[adj_node-1] == '0': # 실외
                    if group_num is None:
                        now_cnt.append(0)
                        dfs(adj_node, len(now_cnt)-1)
                    else:
                        dfs(adj_node, group_num)
                else: # 실내
                    if group_num is not None:
                        now_cnt[group_num] += 1
                    else:
                        total_cnt[0] += 1
                    root_queue.append(adj_node)
    dfs()
    
    for cnt in now_cnt:
        total_cnt[0] += cnt + n_comb_2(cnt)

for node in range(1, N+1):
    if inner_outer[node-1] == '1':
        root_queue.append(node)
        visited[node] = 1
        break

while root_queue: # 메모리 줄이려고..
    root = root_queue.popleft()
    how_many_path(root)

print(total_cnt[0]*2)

# %%
# BFS로 푼 거
from collections import deque
import sys
sys.setrecursionlimit(1000000)
# input = sys.stdin.readline

N = int(input())
inner_outer = input().rstrip()
adj_list = [[] for _ in range(N+1)]
for _ in range(N-1):
    u, v = map(int, input().split())
    adj_list[u].append(v)
    adj_list[v].append(u)

def n_comb_2(n):
    return n*(n-1)//2

total_cnt = [0]
visited = [0]*(N+1)
root_queue = deque()

def how_many_path(root):
    now_cnt = []
    # BFS
    queue = deque([(root, None)])
    while queue:
        now_node, group_num = queue.popleft()
        for adj_node in adj_list[now_node]:
            if not visited[adj_node]:
                visited[adj_node] = 1
                if inner_outer[adj_node-1] == '0': # 실외
                    if group_num is None:
                        now_cnt.append(0)
                        queue.append((adj_node, len(now_cnt)-1))
                    else:
                        queue.append((adj_node, group_num))
                else: # 실내
                    if group_num is not None:
                        now_cnt[group_num] += 1
                    else:
                        total_cnt[0] += 1
                    root_queue.append(adj_node)
    
    for cnt in now_cnt:
        total_cnt[0] += cnt + n_comb_2(cnt)


for node in range(1, N+1):
    if inner_outer[node-1] == '1':
        root_queue.append(node)
        visited[node] = 1
        break

while root_queue: # 메모리 줄이려고
    root = root_queue.popleft()
    how_many_path(root)

print(total_cnt[0]*2)

# %%
# 처음 시도
import sys
sys.setrecursionlimit(100000)
# input = sys.stdin.readline

N = int(input())
inner_outer = input().rstrip()
adj_list = [[] for _ in range(N+1)]
for _ in range(N-1):
    u, v = map(int, input().split())
    adj_list[u].append(v)
    adj_list[v].append(u)

path_cnt = [0]

def how_many_path(root):
    visited = [0]*(N+1)
    visited[root] = 1
    def dfs(node):
        for adj_node in adj_list[node]:
            if not visited[adj_node]:
                visited[adj_node] = 1
                if inner_outer[adj_node-1] == '0': # 실외이면
                    dfs(adj_node)
                else: # 실내이면
                    path_cnt[0] += 1
    dfs(root)

for root in range(1, N+1):
    if inner_outer[root-1] == '1': # 실내에서 시작
        how_many_path(root)
print(path_cnt[0])
